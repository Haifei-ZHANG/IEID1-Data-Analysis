# %% [markdown]
# # TD-1 Data Analysis in Python: pandas, seaborn, and NumPy
#
# The order is:
# 1. **pandas + seaborn**
# 2. **NumPy**
#
# The datasets are stored in the folder `data/` next to this notebook:
# - `data/Iris.csv`
# - `data/s1.csv`
#
# In the **student version**, cells marked with `TODO` are meant to be completed during the lab session.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option("display.max_columns", None)
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. pandas and seaborn

# %% [markdown]
# We begin with **tabular data manipulation** using `pandas`, then we move to **statistical visualization** with `seaborn`.

# %% [markdown]
# ### 1.1 pandas Series: creation

# %%
# TODO:
# Create the following pandas objects:
# - a = Series([1, 2, 3])
# - b = Series(["foo", "bar", "baz"])
# - c = NumPy array [1, 2, 3]
# - d = Series(c)

# %% [markdown]
# ### 1.2 pandas Series: index and access

# %%
# TODO:
# Create a Series named age with values [23, 24, 24, 25]
# and index ["Agathe", "Beatrice", "Cedric", "Donna"].
# Then display:
# - the full Series
# - its index
# - the value associated with "Cedric"

# %% [markdown]
# ### 1.3 DataFrame: creation

# %%
# TODO:
# Create the following DataFrame named df_people:
#   name   age   city
#   Alice  21    Lyon
#   Bob    25    Paris
#   Clara  22    Lille
#
# Then display the DataFrame.

# %% [markdown]
# ### 1.4 Load the Iris dataset

# %%
# TODO:
# Load the file data/Iris.csv into a DataFrame named df.
# Display the first five rows.

# %% [markdown]
# ### 1.5 First inspection

# %%
# TODO:
# Display:
# - df.shape
# - df.columns
# - df.dtypes
# - df.info()
# - df.describe()
#
# Comment:
# df.info() is especially useful to inspect the column types
# and the number of non-missing values.

# %% [markdown]
# ### 1.6 Column selection and row selection

# %%
# TODO:
# Display:
# - the column SepalLengthCm
# - the columns SepalLengthCm and Species
# - the first 5 rows with iloc
# - the first row

# %% [markdown]
# ### 1.7 Filtering

# %%
# TODO:
# Create and display:
# - long_sepals: rows with SepalLengthCm >= 6.0
# - setosa_only: rows with Species == "Iris-setosa"
# - wide_petals: rows with PetalWidthCm > 2.0

# %% [markdown]
# ### 1.8 Descriptive statistics

# %%
# TODO:
# Display:
# - the mean of SepalLengthCm
# - the value counts of Species
# - the descriptive statistics of PetalLengthCm

# %% [markdown]
# ### 1.9 GroupBy

# %%
# TODO:
# Display:
# - the mean SepalLengthCm for each species
# - the mean PetalLengthCm for each species
#
# groupby is one of the most useful pandas tools:
# it allows us to compare statistics between groups.

# %% [markdown]
# ### 1.10 New columns and sorting

# %%
# TODO:
# Create two new columns:
# - sepal_area = SepalLengthCm * SepalWidthCm
# - petal_area = PetalLengthCm * PetalWidthCm
#
# Then display the rows sorted by sepal_area in descending order.

# %% [markdown]
# ### 1.11 Missing values

# %%
# TODO:
# Display the number of missing values in each column.
# Then create a copy called df_clean where rows with missing values are removed.
# Display df_clean.shape

# %% [markdown]
# ## 2. seaborn visualizations

# %% [markdown]
# In this section, we use `seaborn` to quickly visualize distributions, group differences, and relationships between variables.

# %% [markdown]
# ### 2.1 Scatter plot

# %%
# TODO:
# Create a scatter plot of:
# - x = SepalLengthCm
# - y = PetalLengthCm
# - hue = Species
#
# Add a title and display the plot.

# %% [markdown]
# ### 2.2 Histogram

# %%
# TODO:
# Create a histogram of SepalLengthCm with:
# - bins=20
# - kde=True
#
# Add a title and display the plot.

# %% [markdown]
# ### 2.3 Boxplot

# %%
# TODO:
# Create a boxplot of PetalLengthCm grouped by Species.
# Add a title and display the plot.

# %% [markdown]
# ### 2.4 Violin plot

# %%
# TODO:
# Create a violin plot of SepalWidthCm grouped by Species.
# Add a title and display the plot.

# %% [markdown]
# ### 2.5 Pairplot

# %%
# TODO:
# Create a pairplot of the four numerical variables:
# SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm
# with hue="Species".

# %% [markdown]
# ### 2.6 Bar plot from grouped data

# %%
# TODO:
# First compute the mean petal_area for each species.
# Then create a seaborn bar plot from that grouped result.

# %% [markdown]
# ### 2.7 Correlation heatmap

# %%
# TODO:
# Compute the correlation matrix of the numerical columns
# (including sepal_area and petal_area if you created them),
# then display it with a seaborn heatmap.

# %% [markdown]
# ## 3. Small pandas exercise with a second dataset

# %% [markdown]
# We now use the file `data/s1.csv`.
#
# It contains two columns:
# - `prenom`
# - `nombre`
#
# This dataset is useful for simple manipulations such as sorting, filtering, and visualization.

# %%
# TODO:
# Load data/s1.csv into a DataFrame named names.
# Display the first rows and the shape.

# %%
# TODO:
# Display:
# - the 10 most frequent names
# - all rows where nombre > 50000

# %%
# TODO:
# Create a horizontal bar plot of the 10 most frequent names using seaborn.

# %% [markdown]
# ## 4. NumPy

# %% [markdown]
# This second part is more complete.
#
# The goal is to practice:
# - creating arrays,
# - indexing and slicing,
# - reshaping arrays,
# - aggregation,
# - matrix operations,
# - broadcasting,
# - and vectorization.

# %% [markdown]
# ### 4.1 One-dimensional arrays: basic creation

# %%
# TODO:
# Create and display the following arrays:
# - a = np.array([1, 2, 3])
# - b = np.array(range(7))
# - t1 = (1, 10, 100, ..., 10**10)
# - t2 = (0, 2, 4, ..., 100)
# - t3 = (0, -1, -2, ..., -10)

# %% [markdown]
# ### 4.2 One-dimensional arrays: arange, linspace, and like-functions

# %%
# TODO:
# Create and display:
# - c = np.arange(0, 10, 2)
# - d = np.linspace(0, 1, 6)
# - zeros = np.zeros((2, 3))
# - ones = np.ones((3, 2))
# - same_zeros = np.zeros_like(a)
# - same_ones = np.ones_like(a)
#
# Optional:
# - try np.full((2, 3), 7)
# - try np.full_like(a, 100)

# %% [markdown]
# ### 4.3 One-dimensional indexing and slicing

# %%
# TODO:
# Let a = np.arange(2, 12)
# Then display:
# - the second-to-last element
# - elements from index 1 to index -2 with step 3
# - all even-position elements with a[::2]
# - elements from index 1 onward with step 2
# - the array in reverse order with a[::-1]

# %% [markdown]
# ### 4.4 One-dimensional elementary operations

# %%
# TODO:
# Using the array a from the previous question, display:
# - a + 10
# - a - 3
# - 2 * a
# - a / 2
# - a ** 2
# - a % 2
# - np.sqrt(a)

# %% [markdown]
# ### 4.5 One-dimensional aggregation

# %%
# TODO:
# Display:
# - a.sum()
# - a.mean()
# - a.std()
# - a.var()
# - a.min()
# - a.max()
# - a.cumsum()
# - a.cumprod()

# %% [markdown]
# ### 4.6 Manual formulas for the mean and the standard deviation

# %%
# TODO:
# Recompute manually:
# - the mean of a with sum() and len()
# - the standard deviation of a with sum(), len().mean() and sqrt()

# %% [markdown]
# ### 4.7 Multidimensional arrays: creation

# %%
# TODO:
# Create and display:
# - A = np.array([[4, 5, 6], [7, 8, 9]])
# - B = np.zeros((2, 3, 4))
# - C = np.ones((3, 4))
# - D = np.full((2, 3), 3)
# - E = np.zeros_like(D)
# - F = np.ones_like(D)
# - G = np.full_like(D, 100)
#
# Then display the shape of each array.

# %% [markdown]
# ### 4.8 Matrix-specific constructors

# %%
# TODO:
# Display:
# - np.diag([1, 0, 1])
# - np.eye(3)
#
# Then create:
# - A1 = [[1], [-1], [0]]
# - A2 = [-3, -2, 1]
# - A3 : a 3x3 matrix filled with -2 except 0 on the diagonal

# %% [markdown]
# ### 4.9 Reshape

# %%
# TODO:
# Create a = np.arange(4, 10)
# Then reshape it into:
# - a matrix of shape (3, 2)
# - a column vector of shape (6, 1)

# %% [markdown]
# ### 4.10 Reshape exercises with order

# %%
# TODO:
# Use np.arange(1, 9) and reshape to create:
# - M1 = [[1, 2, 3, 4],
#         [5, 6, 7, 8]]
#
# - M2 = [[1, 3, 5, 7],
#         [2, 4, 6, 8]]
#
# Hint:
# - M1 uses the default order
# - M2 can be obtained with order="F"

# %% [markdown]
# ### 4.11 Two-dimensional indexing

# %%
# TODO:
# Let A = np.arange(12).reshape(3, 4)
# Display:
# - A
# - A[0, 1]
# - the first row
# - the last column
# - rows 0 to 1 and columns 1 to 2
# - rows 0 and 2
# - columns 1 and 3
# - all even elements using boolean indexing

# %% [markdown]
# ### 4.12 Interior of a matrix

# %%
# TODO:
# Let A = np.arange(24).reshape(4, 6) + 1
# Extract all elements except those on the outer border.

# %% [markdown]
# ### 4.13 Adding and removing dimensions

# %%
# TODO:
# Let a = np.array([1, 2, 3])
# Display:
# - a.ndim and a.shape
# - b = a[np.newaxis, :]
# - c = a[:, np.newaxis]
# - the ndim and shape of b and c
#
# Then apply squeeze() to b and c.

# %% [markdown]
# ### 4.14 Function exercise: turn a column vector into a row vector

# %%
# TODO:
# Write a function transpose_vector(v)
# that transforms a column vector into a row vector.
#
# Test it on:
# [[1],
#  [2],
#  [3]]

# %% [markdown]
# ### 4.15 Concatenation

# %%
# TODO:
# First, concatenate the 1D arrays [1, 2, 3] and [4, 5, 6].
#
# Then let:
# A = [[1, 2, 3],
#      [4, 5, 6]]
# B = [[7, 8, 9],
#      [10, 11, 12]]
#
# Display:
# - concatenation along axis=0
# - vstack((A, B))
# - concatenation along axis=1
# - hstack((A, B))

# %% [markdown]
# ### 4.16 Function exercise: block matrix

# %%
# TODO:
# Let A1 and A2 be two square matrices.
# Write a function block_matrix(A1, A2) that returns:
#
# [ A1  -A2 ]
# [ A2   A1 ]
#
# Test it on two diagonal matrices.

# %% [markdown]
# ### 4.17 Stacking

# %%
# TODO:
# Let a = np.array([1, 2]) and b = np.array([3, 4])
# Use np.stack to combine them and inspect:
# - the result
# - ndim
# - shape
#
# Then repeat with two 3x3 diagonal matrices and try:
# - axis=0
# - axis=1
# - axis=-1

# %% [markdown]
# ### 4.18 Two-dimensional elementary operations

# %%
# TODO:
# Let
# A = [[1, 4],
#      [3, 2]]
# B = [[5, 6],
#      [7, 8]]
#
# Display:
# - A + 10
# - A - 10
# - 3 * A
# - A / 10
# - A + B
# - A - B
# - A * B
# - A / B
# - A ** 2
# - A % 2
# - np.sqrt(A)
# - np.sin(A)
# - np.exp(A)

# %% [markdown]
# ### 4.19 Two-dimensional aggregation

# %%
# TODO:
# Let A = np.arange(1, 10).reshape((3, 3))
# Display:
# - sums on all elements, by column, and by row
# - means on all elements, by column, and by row
# - minima and maxima on all elements, by column, and by row
# - cumulative sums by column and by row

# %% [markdown]
# ### 4.20 Matrix operations

# %%
# TODO:
# Let
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
#
# Compute the dot product with:
# - np.dot(a, b)
# - a @ b
#
# Then let
# C = np.array([[1, 2], [3, 4]])
# D = np.array([[0, 1], [1, 0]])
#
# Display:
# - the matrix product C @ D
# - the transpose of C
# - the trace of C
# - the inverse of C
# - C_inv @ C

# %% [markdown]
# ### 4.21 Function exercise: harmonic matrix with broadcasting

# %%
# TODO:
# Write a function harmonic_matrix(n, p) that returns the matrix H
# of shape (n, p) such that H[i, j] = 1 / ((i+1) * (j+1)).
#
# Hint:
# Create a column vector u and a row vector v, then combine them.

# %% [markdown]
# ### 4.22 Broadcasting: compatible and incompatible shapes

# %%
# TODO:
# Let
# A = np.array([[1, 2, 3],
#               [4, 5, 6]])
#
# 1) Let B = np.array([10, 20, 30]) and display A + B
# 2) Let C = np.array([[10], [20]]) and display A + C
# 3) Let D = np.array([10, 20]) and try A + D
#
# Observe which cases work and which one raises an error.

# %% [markdown]
# ### 4.23 Vectorization: pairwise Euclidean distances

# %% [markdown]
# We consider a dataset `X` with `N` samples and `D` features.
#
# The goal is to compute the Euclidean distance between every pair of samples:
# $$
# d(x_i, x_j) = \sqrt{\sum_{k=1}^{D}(x_{ik} - x_{jk})^2}.
# $$
#
# First, we prepare the data.

# %%
import time

np.random.seed(0)
N = 4000
D = 10

X = np.random.randint(0, 101, size=(N, D))
X.shape

# %%
# TODO:
# Compute the full pairwise distance matrix with two nested loops.
# Store the result in D_loop.
#
# Suggested structure:
# D_loop = np.zeros((N, N))
# for i in range(N):
#     for j in range(N):
#         ...

# %% [markdown]
# Now compute the same result in a **vectorized** way using the identity
#
# $$
# \|x_i - x_j\|^2 = \|x_i\|^2 + \|x_j\|^2 - 2 x_i^{\top} x_j.
# $$

# %%
# TODO:
# Complete the vectorized version:
#
# sum_X = ...
# D2 = ...
# D2[D2 < 0] = 0
# D_vec = ...
#
# Then compare D_loop and D_vec on a few entries,
# or with np.allclose(D_loop, D_vec).
